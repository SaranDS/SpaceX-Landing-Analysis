# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipython-sql prettytable
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.1 MB 20.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.1 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 12.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.1 kB ? eta -:--:--
#    ---------------------------------------- 46.1/46.1 kB 1.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# ...

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
import pandas as pd

# %%
prettytable.DEFAULT = 'DEFAULT'

# %%
con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# %sql sqlite:///my_data1.db

# %%
df = pd.read_csv("dataset_part_2.csv")

# %%
df.to_sql("SPACEX", con, if_exists='replace', index=False,method="multi")
# Out:
# 90

# %%
# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEX where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql select * from SPACEXTABLE limit 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1, '2010-06-04', 'Falcon 9', 6123.547647058824, 'LEO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0003', -80.577366, 28.5618571, 0),
#  (2, '2012-05-22', 'Falcon 9', 525.0, 'LEO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0005', -80.577366, 28.5618571, 0),
#  (3, '2013-03-01', 'Falcon 9', 677.0, 'ISS', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B0007', -80.577366, 28.5618571, 0),
#  (4, '2013-09-29', 'Falcon 9', 500.0, 'PO', 'VAFB SLC 4E', 'False Ocean', 1, 0, 0, 0, None, 1.0, 0, 'B1003', -120.610829, 34.632093, 0),
#  (5, '2013-12-03', 'Falcon 9', 3170.0, 'GTO', 'CCSFS SLC 40', 'None None', 1, 0, 0, 0, None, 1.0, 0, 'B1004', -80.577366, 28.5618571, 0)]

# %%
# %sql select Distinct LaunchSite from SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCSFS SLC 40',), ('VAFB SLC 4E',), ('KSC LC 39A',)]

# %%
# %sql select Outcome, count(*) from SPACEXTABLE group by Outcome
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('False ASDS', 6),
#  ('False Ocean', 2),
#  ('False RTLS', 1),
#  ('None ASDS', 2),
#  ('None None', 19),
#  ('True ASDS', 41),
#  ('True Ocean', 5),
#  ('True RTLS', 14)]

# %%
# %sql select substr(Date,6,2) as month, Outcome, BoosterVersion,LaunchSite from SPACEXTABLE where substr(Date,1,4) ='2015' and Outcome = 'False ASDS'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01', 'False ASDS', 'Falcon 9', 'CCSFS SLC 40'),
#  ('04', 'False ASDS', 'Falcon 9', 'CCSFS SLC 40')]
